# %% [markdown]
# # **Working memory training**: Module allegiance matrix calculation
#
# **Last edited:** 05-07-2020

# %% [markdown]
# Step 0:  Loading libraries
# --------------------------------

# %%
import sys
sys.path.append("..")
import os

# %matplotlib inline

import scipy.io as sio
import numpy as np
from nilearn import plotting
import pandas as pd
import seaborn as sns

from scipy import stats
from fctools import networks, figures

#---- matplotlib settings
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
plt.rcParams['font.family'] = 'Helvetica'

# %% [markdown]
# Step 1: Getting module names
# ----------------------------------------

# %%
labels = pd.read_csv('Functional_system_data/Alphabetical/module_names_alphabetical.txt', sep = " ", header = None)
modules = labels[0].values

# %% [markdown]
# Step 2: Loading module assignment matrices
# -------------------------------------------------------------------------------

# %%
mat = sio.loadmat('../Subject_data_and_analysis/Community_detection/modules.mat') # Load community assignment matrix
module_assignment = mat['modules']



#idx = np.argsort(labels[0]) # Get the alphabetical order of the modules

idx = pd.read_csv('Functional_system_data/Alphabetical/module_order_alphabetical.txt', sep = " ", header = None)
module_assignment = module_assignment[:, idx, :, :, :]
module_assignment = np.squeeze(module_assignment)
module_assignment[0,:,0,0,0]
module_assignment.shape
# Out:
# (100, 98, 28, 6, 30)

# %% [markdown]
# Step 3: calculating allegiance matrices
# -------------------------------------------

# %%
# Calculating allegiance matrices (mean over optimizations)

n_opt = module_assignment.shape[0] # number of optimisations of genLouvain algorithm
n_nod = module_assignment.shape[1] # number of ROI
n_lay = module_assignment.shape[2] # number of layers/time windows
n_fun = module_assignment.shape[3] # number of frequency/functional bands
n_sub = module_assignment.shape[4] # number of subjects

P = np.zeros((n_nod, n_nod, n_fun, n_sub))

for j in range(n_sub):
    print(f'Subject number {j+1}')
    for i in range(n_fun):
        print(f'Functional band {i+1}')
        P[:,:,i,j] = networks.allegiance_matrix_opti(module_assignment[:,:,:,i,j]) 
        # the function allegiance_matrix_opti calculates n x n allegiance matrix P from n x t matrix M, where n 
        # represents nodes, and t represents time windows. Each value on allegiance matrix P represents the 
        # probability that node i and node j have been assigned to the same community.
        # This is averaged out over the 100 optimisations run of the genLouvain algorithm.
        
    
np.save('../Subject_data_and_analysis/Modular_allegiance_matrix/allegiance_matrix_opt_mean.npy',P)
sio.savemat('../Subject_data_and_analysis/Modular_allegiance_matrix/allegiance_matrix_opt_mean.mat', {'P':P})
# Out:
# Subject number 1
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 2
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-3e49ddc9f958> in <module>
#      13     for i in range(n_fun):
#      14         print(f'Functional band {i+1}')
# ---> 15         P[:,:,i,j] = networks.allegiance_matrix_opti(module_assignment[:,:,:,i,j])
#      16         # the function allegiance_matrix_opti calculates n x n allegiance matrix P from n x t matrix M, where n
#      17         # represents nodes, and t represents time windows. Each value on allegiance matrix P represents the
#
# ~/git_repos/Dyngraph/dyngraph-pain/Dynamic_modular_analyses/fctools/networks.py in allegiance_matrix_opti(M)
#     116
#     117     for i in range(n_optimizations):
# --> 118         P[i, :, :] = allegiance_matrix(M[i, :, :])
#     119         PO = P.mean(axis = 0)
#     120     return PO
#
# ~/git_repos/Dyngraph/dyngraph-pain/Dynamic_modular_analyses/fctools/networks.py in allegiance_matrix(M)
#      65                 continue
#      66             else:
# ---> 67                 t = np.sum(M[i, :] == M[j, :])
#      68                 T[i, j] = t
#      69
#
# KeyboardInterrupt:

# %%
# Calculating allegiance matrices for each layer/time window (mean over optimizations)

n_opt = module_assignment.shape[0] # number of optimisations of genLouvain algorithm
n_nod = module_assignment.shape[1] # number of ROI
n_lay = module_assignment.shape[2] # number of layers/time windows
n_fun = module_assignment.shape[3] # number of frequency/functional bands
n_sub = module_assignment.shape[4] # number of subjects

W = np.zeros(( n_lay, n_nod, n_nod, n_fun, n_sub))
for j in range (n_sub):
    print(f'Subject number {j+1}')
    for i in range(n_fun):
        print(f'Functional band {i+1}')
        W[:,:,:,i,j] = networks.all_window_allegiance_mean(module_assignment[:,:,:,i,j])

np.save('../Subject_data_and_analysis/Modular_allegiance_matrix/window_allegiance_matrix_opt_mean.npy',W)
sio.savemat('../Subject_data_and_analysis/Modular_allegiance_matrix/window_allegiance_matrix_opt_mean.mat', {'W':W})
# Out:
# Subject number 1
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 2
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 3
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 4
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 5
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 6
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 7
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 8
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 9
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 10
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 11
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 12
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 13
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 14
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 15
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 16
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 17
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 18
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 19
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 20
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 21
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 22
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 23
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 24
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 25
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 26
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 27
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 28
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 29
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
# Subject number 30
# Functional band 1
# Functional band 2
# Functional band 3
# Functional band 4
# Functional band 5
# Functional band 6
